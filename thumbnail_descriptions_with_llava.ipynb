# %%
#the code lasts hours but working

import os
import glob
import base64
import json
import csv
import requests

IMAGE_DIR   = "thumbnails_travel"   
OUTPUT_CSV  = "thumbnail_descriptions_llava.csv"
OLLAMA_URL  = "http://localhost:11434/api/generate"
MODEL_NAME  = "llava:7b"               
PROMPT      = "Describe this YouTube thumbnail in one detailed sentence, focusing on what is visually shown and the style."


def encode_image_to_base64(path: str) -> str:
    with open(path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")


def describe_with_llava(image_path: str) -> str:
    img_b64 = encode_image_to_base64(image_path)

    payload = {
        "model": MODEL_NAME,
        "prompt": PROMPT,
        "stream": False,
        "images": [img_b64],
    }

    resp = requests.post(OLLAMA_URL, json=payload)
    resp.raise_for_status()

    data = resp.json()
    caption = data.get("response", "").strip()
    print(caption)
    return caption


def main():
    exts = ("*.jpg", "*.jpeg", "*.png", "*.webp")
    img_paths = []
    for ext in exts:
        img_paths.extend(glob.glob(os.path.join(IMAGE_DIR, ext)))

    if not img_paths:
        print(f"[WARN] No images found in {IMAGE_DIR}")
        return

    print(f"[INFO] Found {len(img_paths)} thumbnails.")

    rows = []
    for i, path in enumerate(sorted(img_paths), start=1):
        print(f"[{i}/{len(img_paths)}] Captioning {path} ...")
        try:
            caption = describe_with_llava(path)
        except Exception as e:
            print(f"   [ERROR] {path}: {e}")
            caption = ""

        rows.append({
            "filename": os.path.basename(path),
            "path": path,
            "description": caption,
        })

    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["filename", "path", "description"])
        writer.writeheader()
        writer.writerows(rows)

    print(f"[DONE] Saved descriptions to {OUTPUT_CSV}")


if __name__ == "__main__":
    main()
# Out:
# [INFO] Found 18444 thumbnails.
# [1/18444] Captioning thumbnails_travel/--27C2-_56U.jpg ...
# The image features a woman holding a cardboard box while standing in front of a house with a sign that reads "apartment hunting alone" in bold text. The thumbnail has an informative design style, including bullet points highlighting different aspects such as "18", "DIY", "moving diaries", and "2 moving diaries". There's also a playful tone to the image with the inclusion of cartoon elements like pizza boxes and a broken heart. The overall aesthetic is vibrant and engaging, designed to catch viewers' attention with its mix of text and visual elements.
# [2/18444] Captioning thumbnails_travel/--9KQM9LsU8.jpg ...
# The image is a composite of two separate photographs with text overlaying both. On the left side, there's a photo of a woman eating food from a bowl while making a humorous facial expression; she is seated at a table and appears to be in a restaurant or similar setting. On the right, there's another photo showing a person with a black hairstyle holding a green drink with a straw and smiling at the camera. The background of this second image seems to be outdoors, possibly on a street. In the middle, connecting both photos, is text in Portuguese that reads "Come mosso como um bolo de chocolate!" which translates to "Eat me as a chocolate cake!" indicating a playful exchange between the two individuals. The overall style of the thumbnail is informal and humorous, likely intended for an entertaining video.
# [3/18444] Captioning thumbnails_travel/--CZMPVa4qs.jpg ...
# The image is a vibrant and cheerful YouTube thumbnail for a channel or video titled "KAPADOKYA VLOG". A woman, who appears to be the main subject, is shown smiling brightly against a backdrop featuring colorful hot air balloons with the word "Kapadokya" written on them. The text "VLOG" and "כפודיה בלוגים" suggest that this is likely a personal vlog or travel diary series. There's an element of adventure implied by the presence of hot air balloons, suggesting that this could be about travel experiences or adventures in Kapadokya. The overall style of the image seems friendly and inviting, potentially aimed at attracting viewers who are interested in exploring new places and cultures.
# [4/18444] Captioning thumbnails_travel/--Ovm-KBvuw.jpg ...
# The image displays a vibrant nighttime cityscape featuring a large European square with architectural elements that suggest a Spanish influence. In the foreground, there's a woman posing for a photo; she has sunglasses on and is wearing a dark top with a red scarf tied around her neck. Above her, a text overlay states "Sevilla this is Spain?" in bold white letters, which conveys an interactive invitation to viewers, implying that the location might not be immediately obvious from the image. The thumbnail has a bright and cheerful style, indicative of travel content aimed at providing a glimpse into the destination's atmosphere and culture.
# [5/18444] Captioning thumbnails_travel/--h9KUBV_gM.jpg ...
# The image is a photograph featuring two individuals standing outdoors; the person on the left is a woman with blonde hair wearing a blue headband, a black sleeveless top, a necklace, and sunglasses, standing beside a man who has dark skin, is wearing a black t-shirt, and has a camera strap around his neck. The text "SCARIFICATION" is superimposed over the image in bold white font with a red outline.
# [6/18444] Captioning thumbnails_travel/-090QZwzvbU.jpg ...
# The image captures a cozy indoor setting where a group of people is gathered around a large projection screen displaying an engaging video. A comfortable couch serves as their seating arrangement, with a coffee table in front for snacks or drinks. The ambiance is further enhanced by the warm and inviting glow of the television screen and the soft lighting emanating from above. The overall style of the image conveys a sense of togetherness and enjoyment shared among friends or family during their leisure time.
# [7/18444] Captioning thumbnails_travel/-0Hul4ALOuw.jpg ...
# The image features a split-style YouTube thumbnail with two distinct sections. On the left side of the thumbnail, there's a photograph of a group of people standing in front of a building, posing for a photo with the cityscape visible behind them. They are dressed in casual streetwear and one person is holding up their hand with their finger on their lips. The building has multiple windows and signs that read "ACE'S PLACES," indicating it might be a venue or business location.
#
# On the right side of the thumbnail, there is a photograph of the same group of people standing together in front of the building, but this time they are posing with their heads behind a digital overlay that distorts and distorts their features. They appear to be on a social media platform, as indicated by the interface elements such as 'like,' 'share,' and comment icons visible at the bottom of the image. The overlay text "SVOG" is superimposed in white letters against a black background in the right side of the photo, possibly indicating an Instagram handle or username.
#
# The overall style of the thumbnail is split-style, with two distinct photographs arranged vertically on either side of the central dividing line, creating a juxtaposition between the real and the distorted image. The left photograph has a realistic look, while the right photograph features an artistic, filtered effect that adds to the visual interest and possibly implies a theme of social media or digital manipulation.
# [8/18444] Captioning thumbnails_travel/-0V8AsrcBwU.jpg ...
# The image is a screenshot from a video sharing platform featuring an advertisement for the "Daily in Tangier" channel. It captures a moment of someone taking a selfie with palm trees in the background, symbolizing a relaxing atmosphere. In the foreground, there's a woman posing confidently while holding a smartphone, and she is surrounded by three circular icons, each containing an image of different individuals from the channel. The text "Daily in Tangier" is prominently displayed, suggesting that this is a promotional content meant to showcase the variety of personalities featured on the channel. The overall style of the image conveys a sense of fun and casualness.
# [9/18444] Captioning thumbnails_travel/-0c42X7JEaQ.jpg ...
# The thumbnail of a YouTube video features an image of a woman smiling at the camera with a collage of various foods, including dumplings and skewers, overlaid on her head. The background shows a clear sky, suggesting good weather. Text overlays include "3 DAYS IN BEIJING" and a playful, bold, white font that reads "12 HOURS." The style is colorful and food-centric, intended to attract viewers interested in culinary experiences.
# [10/18444] Captioning thumbnails_travel/-0dhAfEcPhA.jpg ...
# The image appears to be a meme or a humorous composite featuring two photographs placed vertically next to each other, side by side. In the left photograph, there's an animated character with exaggerated features sitting at a table with a plate of pizza. The character is holding up a slice of pizza and seems surprised or shocked, as indicated by the wide-eyed expression and open mouth. Above this character, there's a text overlay stating "$100" in bold, stylized letters, suggesting that the character is excited about receiving free pizza.
#
# In the right photograph, there are two men sitting at a similar table with another plate of pizza. Both men appear to be dressed casually and are holding up pizza slices towards the camera as if they are enjoying their meal. One man is holding up a slice with his left hand, while the other is not visible in this particular frame. Above them, there's a text overlay that reads "Pizza Party," and below it, there's another price tag showing "$200" in bold, stylized letters.
#
# The style of the image suggests a playful or satirical tone, likely intended to generate humor through the exaggerated reactions and contrasting prices for pizza. The background of both images is simple and does not draw attention away from the subjects or the price tags, which are the main focal points of the thumbnail. The meme seems to be designed for sharing on social media platforms like YouTube, where such images are often used to grab attention and spark engagement with content related to food or humor.
# [11/18444] Captioning thumbnails_travel/-0sybTpJ3x4.jpg ...
# The image is a digital artwork with a vintage computer screen aesthetic, featuring a monochrome photograph of an individual who appears to be a singer or musician on the right side. They are wearing dark clothing and have short hair. To the left of the photograph, there's a pixelated blue and white bar displaying the text "LOUIS COLE" in bold, capital letters. The overall style is reminiscent of an older computer interface with a retro-futuristic vibe, emphasizing nostalgia and visual artistry.
# [12/18444] Captioning thumbnails_travel/-1Mgse9M9wM.jpg ...
# The image displays a collage-style thumbnail for a travel vlog featuring a woman posing with a backdrop of a scenic outdoor area. In the foreground, there's a photo of her reacting to something in front of a sign that reads "schengen" and another one indicating 250 Euro cost. The background showcases a landscape with hills under a cloudy sky, and she is standing near the water with the caption "India to Greece 7 days / 1,893 km." Text overlaid on the image suggests "Cost of travelling in India ₹ 1,89,000" and "Total cost for my 7 day, 1,590 km trip". The thumbnail has an informative and candid feel, capturing a moment from her journey.
# [13/18444] Captioning thumbnails_travel/-1u7Iwbgm8o.jpg ...
# The image is a collage of three photos showing a woman taking a selfie with her phone against a backdrop of city buildings during sunset, a laptop screen displaying food items, and a montage of morning routines featuring personal grooming and breakfast foods, presented as a thumbnail for a YouTube video.
# [14/18444] Captioning thumbnails_travel/-1wK_UO_8dQ.jpg ...
# The thumbnail features two images with a collage-like design, set against a backdrop of an urban street scene, showcasing a person holding an umbrella in the rainy weather and another individual posing for a selfie. The top image captures a moment of rainfall, with a greenish hue dominating the scene. The bottom image is a close-up portrait of a person, possibly a musician or influencer, dressed in fashionable attire, looking directly at the camera with a confident expression. In the center, a text overlay reads "OSAKA," which suggests that both images are related to Osaka or showcasing a moment from there. The thumbnail has a vibrant and artistic feel, typical of YouTube content aimed at showcasing travel, lifestyle, or cultural experiences.
# [15/18444] Captioning thumbnails_travel/-2W1T_85bS8.jpg ...
# This image features a man sitting at a bench, overlooking a picturesque coastal scene with waves gently breaking against the shoreline. The man appears to be looking out towards the sea and has a notebook and pen before him, suggesting he might be taking notes or drawing the scenery. Above him, a small portion of the sky is visible, showing it's either sunrise or sunset due to the soft, warm light illuminating the scene. The landscape is dotted with vegetation, including what looks like trees and shrubs, and in the distance, a person is faintly visible walking along the beach. The overall style of the image conveys a sense of calm and contemplation, with an emphasis on the natural beauty of the location and the man's connection to it.
# [16/18444] Captioning thumbnails_travel/-3CcMhky0KU.jpg ...
# The image features a vibrant, daytime cityscape with the Sydney Opera House prominently visible across the water, under a clear blue sky. In the foreground, there's a smiling woman in a sleeveless top, with her arm lifted towards the camera as if celebrating or gesturing enthusiastically. Superimposed over the image is text that reads "PERFECT 3 DAY ITINARY SYDNEY." The text and the woman's pose suggest a positive and exciting travel experience to Sydney. The style of the image is a mix between a travel poster and a personal vlog thumbnail, designed to attract viewers interested in travel planning or looking for recommendations on what to see and do in Sydney.
# [17/18444] Captioning thumbnails_travel/-3rCQIK6exw.jpg ...
# The image features a vibrant collage of three distinct photos, each capturing a unique moment of travel. In the top left photo, we see an overhead view of a lush green park with a striking blue sky, while in the top right corner, there's a photo of a person holding a plate of food amidst a restaurant setting. The bottom photo presents another individual, this time in the midst of a poolside gathering, surrounded by colorful decorations and an inviting swimming pool. Atop the collage, text proudly announces "WHEN IN PHUKET + DUBAI", indicating the destinations these images represent.
# [18/18444] Captioning thumbnails_travel/-4CETaEOQDs.jpg ...
# The image appears to be a screenshot from a video featuring three people with two individuals taking a selfie, capturing a moment where they seem to be posing for a photo. The person at the center is pointing at another individual in the background, possibly indicating something interesting or relevant. The focus is on the three main subjects, with the other person in the background slightly blurred and less prominent. There's text overlaid on the image that reads "XIAN CHINA," with a red star symbolizing China. Additionally, there are Chinese characters above the image. The style of the image suggests it may be related to travel or cultural content, with a focus on capturing the essence of China and its people in a real-life context.
# [19/18444] Captioning thumbnails_travel/-4JnVrqChN8.jpg ...
# The image features a woman standing on a terraced field with tea plants, wearing a red blouse and holding her hand up to her eyes, saluting. Behind her is a picturesque landscape of a town and mountains, under a sky with visible clouds. Superimposed on the photo are Chinese characters that read "Hangzhou" and below them, an emoji of a smiling face and the English text "China." The woman is also holding a smartphone in one hand. The style of the image suggests it may be related to travel or tourism content.
# [20/18444] Captioning thumbnails_travel/-4TqN9S_-Ds.jpg ...
# The image is a digital composite of two distinct sections. On the left side, there's a collage of images featuring a man with tattoos on his arms, donning sunglasses, posing with women dressed in stylish streetwear. He has a beard and mustache and appears to be in a casual, relaxed setting. The right side features another man, seemingly in a different context, holding a cardboard cutout of the same tattooed individual. The backgrounds are urban, with buildings and outdoor cityscapes visible, adding to the overall street vibe.
# [21/18444] Captioning thumbnails_travel/-4kzBmmGyhA.jpg ...
# The thumbnail is a split image of two photos. On the left side, there's a photo of a man wearing sunglasses, a denim jacket, and jeans standing indoors, seemingly preparing to dance as he faces his reflection in the mirror. His pose suggests he is about to perform or imitate an action captured in the other photo on the right. The right side shows another man looking at the camera while wearing a white shirt, glasses, and holding what appears to be a small object in his hand; it's unclear whether this object is a phone or a remote control. In both photos, they are set against indoor backgrounds.
# [22/18444] Captioning thumbnails_travel/-4ztcBC6G2g.jpg ...
# The image is a split-screen collage thumbnail for a video, featuring two contrasting scenes with text elements to highlight a comparison. On the left, there's a photograph of a young man in casual clothing performing an exaggerated action pose, mimicking a popular Japanese anime gesture by holding his hands high above his head and opening his mouth wide as if shouting. The right side of the image shows a similar figure standing on top of a bookshelf, with text reading "$10", indicating that this might be a comparison between the cost of an item or service in two different scenarios. The style is a meme-like thumbnail with bold colors and exaggerated gestures to emphasize the content of the video, which likely involves humor and commentary on pricing or value for money.
# [23/18444] Captioning thumbnails_travel/-5PxDKOfzv0.jpg ...
# The image features a person standing against a backdrop of a city skyline at sunset, with a bridge and skyscrapers visible, while text overlay at the bottom reads "DHAKA TO CHINA" in bold letters.
# [24/18444] Captioning thumbnails_travel/-5qzMWlsajY.jpg ...
# The image is a composite of two separate photographs related to seafood cuisine. In the top photo, there's an overhead view of a dining table with multiple pieces of cooked seafood arranged neatly across it. The food appears to be prepared in a restaurant setting, possibly for tasting or showcasing purposes, and is presented artistically.
#
# In the bottom photo, there is a man who seems to be a chef or restaurateur, standing next to a whiteboard with text that reads "tourism" and "food." The chef is wearing a black shirt with a logo on it, and he's holding a spoonful of food in his mouth, looking towards the camera as if posing for the image. His expression is cheerful and confident, suggesting that he takes pride in his culinary creations.
#
# The style of the composite appears to be informational or promotional in nature, aimed at highlighting the seafood dish and its potential appeal for tourists seeking food experiences. The images are likely used on a platform like YouTube to attract viewers interested in learning more about seafood cuisine or to entice them with visually appealing and mouthwatering food presentations.
# [25/18444] Captioning thumbnails_travel/-66ALKwi22w.jpg ...
# The image is a photograph of two people posing for a photo in front of a restaurant table with various dishes. On top of the image is an overlay text that reads "10 INTERESTING PLACES TO EAT IN HANGZHOU" in white font on a black background, with Chinese characters beneath it indicating the content may be related to dining or travel advice. The style of the image suggests it could be used as a thumbnail for a YouTube video showcasing places to eat in Hangzhou, China.
# [26/18444] Captioning thumbnails_travel/-6AKL_oUY34.jpg ...
# The image is a composite of four smaller images arranged vertically to form a larger collage. The top left shows a person's hands holding a plate with a red object that appears to be an apple or a fruit, which is in motion, as suggested by a blurred effect. Below it on the right side, there's a close-up of a person taking a selfie with a front camera. The middle left image features a window with light filtering through, showing a peaceful indoor scene. The bottom left depicts a kitchen area with a sink and some kitchen items visible. In the bottom right image, a hand holding an orange object is shown against a blurred background that suggests a moving object, possibly indicating movement or action. Each image has text overlaying it: "living alone in korea" on the top left, "am to 5pm in Korea" on the top right, and "day by day" at the bottom right corner. The overall style of the thumbnail suggests a vlog format, possibly indicating daily life activities from an individual living alone in Korea. The thumbnail is designed to be eye-catching and informative, capturing different moments from the individual's day.
# [27/18444] Captioning thumbnails_travel/-6kqGcRp2os.jpg ...
# The image appears to be a screenshot from a YouTube video with a celebratory theme. It features a man and a woman standing close together, smiling and looking at something off-camera. The text overlay indicates that the man is making his first trip to Athens to celebrate his first anniversary in Athens, suggesting a personal milestone. The style of the image seems candid and joyful, with a focus on the subjects' happiness and connection to each other. The text itself is clear and informative, conveying both the purpose of the image and the special occasion being celebrated.
# [28/18444] Captioning thumbnails_travel/-6rEmucEAmw.jpg ...
# The image is a collage of two photographs featuring an individual sitting against a wall in a relaxed pose. On the left side of the image, there's a person wearing a gray sleeveless top sitting down on what appears to be a bench or chair, with their legs crossed at the ankles and one hand resting on their knee. The background is blurred but it looks like an outdoor setting with greenery. On the right side of the image is another photo where the person has changed into a darker top and is still seated against the wall, which now has some decorative elements visible in the background, including what appears to be a framed certificate or award above them. The style of the image suggests that it might be promotional material for an event, a show or an article, given the text overlay on both photos.
# [29/18444] Captioning thumbnails_travel/-6xMwJL9QEk.jpg ...
# The image is a rectangular thumbnail featuring a male musician playing drums with his back turned to the camera. He has glasses on his head and is wearing a white baseball cap with a backwards logo. His attire includes a dark shirt with an image or text near the neckline. The background of the photo appears to be dimly lit, highlighting the drum set and the musician's focused expression. The style of the image suggests it may be from a concert or live performance setting.
# [30/18444] Captioning thumbnails_travel/-6z9mUyFBiw.jpg ...
# This image features a collage of three photos placed side by side against a backdrop that resembles a green hillside or cliff. In each photo, there are individuals wearing red jackets with yellow accents, suggesting they may be a group of adventurers or part of an organization such as the coast guard. The people are smiling and seem to be enjoying themselves in various outdoor settings. The top left photo captures them on what appears to be a roadside, with one person pointing upwards as if directing attention towards something out of frame. The top right photo shows them standing near a body of water with hazy mountains in the background, implying they are in a remote or scenic location. The bottom left photo is similar to the first, but the individuals are posing differently, one person waving and the others looking directly at the camera.
#
# Text is overlaid on top of the collage, with the words "ICELAND" in bold red letters and "More Drew Binsky" in white text in the bottom right corner. The style of the thumbnail suggests a travel or adventure theme, with an emphasis on outdoor activities and camaraderie among the individuals depicted. The use of vibrant colors and the variety of locations contribute to an energetic and dynamic presentation.
# [31/18444] Captioning thumbnails_travel/-7RTgx8klL0.jpg ...
# The image is a digital composite or overlay with photographic elements. At the top of the image, there's a photo of a young woman who appears to be speaking to the camera, looking directly at it with a neutral expression. Below her is a text that reads "AMERICANS IN ARGENTINA" in bold, capital letters. The style of the image suggests it could be related to a video blog or a series about the experiences of Americans living in Argentina. Overlaid on top of the woman's photo are two small flags, one representing the United States and the other representing Argentina. The overall layout is clean and straightforward, with a clear focus on the text and the flags.
# [32/18444] Captioning thumbnails_travel/-8hLXWptlWU.jpg ...
# The image appears to be a photo mosaic featuring various snapshots, possibly from a family's trip to the Philippines. It includes diverse elements such as an older man walking with two children, a collage of pictures showing different scenes and people, including some with text overlaying the images. There is also a mention of a family member having their 1st flight in Cebu, Philippines, suggesting travel and adventure themes. The style is informal and collage-like, intended to convey personal memories and experiences.
# [33/18444] Captioning thumbnails_travel/-9M3SXco1IE.jpg ...
# The thumbnail features a nighttime cityscape from a window with the words "Hong Kong" prominently displayed at the center against a backdrop of a person working at their desk near an open window.
# [34/18444] Captioning thumbnails_travel/-9b_qpEmolo.jpg ...
# The image is a bright, colorful photo of a person standing outdoors with their hand raised and fingers pointing upwards towards text that reads "Paris Vlog". They are giving a thumbs-up gesture to the camera, wearing sunglasses and a red top. Behind them, there is a vibrant sky and the iconic Eiffel Tower in the distance. The photo has a playful and cheerful vibe, possibly suggesting a positive travel experience or a recommendation for visiting Paris.
# [35/18444] Captioning thumbnails_travel/-9cSHMgVxsU.jpg ...
# The image appears to be a graphic design for a YouTube video thumbnail featuring a woman pointing at a colorful tropical island with an overlay text that reads "BEST OF COLOMBIA". The woman is holding up her pointer finger towards the island, which has a small dock with boats and palm trees. She has blonde hair and is wearing a black top. Her facial expression is one of surprise or amazement. The text "BEST OF COLOMBIA" is superimposed over the image in yellow letters on a transparent black background. The overall style of the thumbnail is vibrant, with a focus on travel and exploration. The image seems to be designed to entice viewers into watching a video about the best sights in Colombia.
# [36/18444] Captioning thumbnails_travel/-9eW8Xk0VOU.jpg ...
# The YouTube thumbnail is a collage of three photos with a summer vacation theme. It features two women, one dressed in white overalls standing next to a blue building with a white roof under a clear sky, and the other woman posing in front of a beach view with a text that reads "Táanger Day". The background shows an idyllic coastal scene with palm trees and a clear sky. There are also images of pizza and dining, indicating food and leisure. In the foreground, there is a handbag placed to the left side. The collage conveys a relaxed and fun atmosphere associated with summer travels.
# [37/18444] Captioning thumbnails_travel/-9iirWXm844.jpg ...
# The image is a composite of several photos showcasing different travel destinations. At the center is a photo of a man and woman posing together with the background featuring a colorful rainbow. Above them are two more photos: one showing a scenic view with a train, possibly a tourist attraction, and another depicting a cityscape with various vehicles. The surrounding pictures feature iconic landmarks such as waterfalls, bridges, and boats, which are typical sights at tourist destinations. To the right, there's a photo of a hotel or motel room. The images are arranged neatly in a grid format, and they all share the common theme of travel and leisure. A text box overlaying the collage contains information about the content, which is presumably related to traveling to Iceland for a 6-day/5-night trip at an affordable price. The overall style of the image suggests it might be used as a promotional or informative thumbnail for a travel vlog or tutorial.
# [38/18444] Captioning thumbnails_travel/-A5WZRWXusU.jpg ...
# The image appears to be a composite of two photographs, each with its own text. The upper photo shows an outdoor setting with Japanese-style food items like tempura and drinks, alongside a sign that reads "KYOTO." There are also cups and a dining table in the background, as well as some plants adding a touch of greenery to the scene.
#
# The lower photo captures a different aspect of KYOTO, featuring various Japanese dishes on plates, displayed on what seems to be a counter or dining table within an indoor setting with a red and white sign that reads "KYOTO" in the background. The text at the bottom of both photos is "2 days in Kyoto," suggesting a thematic connection between the images, possibly showcasing different aspects of dining experiences in Kyoto over two days.
# [39/18444] Captioning thumbnails_travel/-AE27zdTtzs.jpg ...
# The image depicts a man standing in front of a significant historical site with Greek columns, wearing a black t-shirt. He has short hair and is smiling at the camera. In the background, there's a small flag or banner hanging from the left side of the structure. The sky is clear with no visible clouds, suggesting it might be midday. There are no texts or additional objects in the frame. The style of the image appears to be a personal photograph, possibly taken by the man himself, capturing a travel moment or a visit to a cultural landmark.
# [40/18444] Captioning thumbnails_travel/-AW5XuwqCJM.jpg ...
# The thumbnail is a split image featuring two women; the top half shows an individual with long hair walking towards the camera, smiling slightly, dressed casually in a white top, against a blurred backdrop of lush greenery and a palm tree. The bottom half displays another woman standing amidst what appears to be an urban park setting, holding a handbag, with a clear sky above her and text overlaying the image in white and pink that reads "ENDLESS SUMMER IN BUNOS AIRIES" in large letters. The overall style of the thumbnail suggests a travel vlog or lifestyle content related to summer experiences in Buenos Aires, with the top half conveying relaxation and leisure and the bottom half evoking a sense of adventure and exploration.
# [41/18444] Captioning thumbnails_travel/-AiFb49hr-8.jpg ...
# The image is a collage of various photographs that show a woman posing in front of a scenic beach backdrop, with an overlay text "THAILAND" prominently displayed across the center, suggesting the theme of travel or vacation to Thailand.
# [42/18444] Captioning thumbnails_travel/-Ayk3muSILs.jpg ...
# The image is a rectangular, landscape-oriented photograph featuring a smiling woman with short hair, posing for the camera with her right hand holding a smartphone close to the frame. In front of her is a dirt bike, parked on a street adjacent to a single-story house and overgrown shrubbery. The background includes a clear sky, suggesting it's a sunny day. There are also some text elements present: in the upper right corner, there's a watermark that reads "Ready to Race," with the same phrase repeated as an overlay text in the foreground. The style of the image is informal and appears to be taken during a personal outdoor activity or event related to motorcycling.
# [43/18444] Captioning thumbnails_travel/-BWJvsTfzM4.jpg ...
# The image appears to be a composite of several smaller images collaged together to create a single visual message. It features a screenshot from a social media platform with overlays including text and emojis, and an edited picture of a man holding a sandwich and smiling at the camera. The top portion of the image contains a Brazilian flag in one corner, suggesting a theme related to Brazil or a review about Brazilian food. The central portion of the image displays a thumbnail for a video titled "HONEST REVIEW STREET FOOD," which implies that the content of the video pertains to street food in the context of honest reviews. The bottom left corner shows a man holding a sandwich and looking surprised, which further reinforces the theme of street food. The overall style of the image suggests it is meant for an audience interested in Brazilian cuisine or seeking honest reviews of street food options.
# [44/18444] Captioning thumbnails_travel/-Bd5ToRCj1k.jpg ...
# The thumbnail for a YouTube video captures an eclectic scene featuring various aspects of Indian cuisine and culture. Dominating the top right corner is a text "MUMBAI LOG" which suggests that the content might be related to food or life in Mumbai. Below this, there's a picture of what appears to be a meal consisting of samosas and curry, possibly indicating a recipe or review.
#
# In the bottom left corner, there's an image of a woman walking past a sign that reads "MUMBAI", which aligns with the theme mentioned above. This photo seems to capture the essence of everyday life in the city. Further on the left, there's a food item labeled "Bhaji Puri" along with some condiments and snacks, perhaps showcasing popular street food items from Mumbai.
#
# To the right of this, there's an image of a person holding up a burger with a side of chips, which could be an example of fusion cuisine or an alternative to traditional Indian meals. This suggests that the video may cover a variety of culinary options available in Mumbai.
#
# Finally, on the bottom right corner, there's a picture of a person holding up a sign with "MUMBAI" written on it and the word "Bhaji" below it, which is a common dish associated with Indian street food. The collage as a whole seems to be a vibrant representation of the diverse culinary scene in Mumbai, inviting viewers to explore its flavors through this video.
# [45/18444] Captioning thumbnails_travel/-Bko2yexcRE.jpg ...
# The thumbnail for a video titled "New York" is a collage of various images featuring the cityscape of New York. It showcases iconic landmarks like the Statue of Liberty and the Empire State Building, as well as street scenes, including a person wearing a fur coat walking on a sidewalk with stores in the background. The image also includes a city bus and a pedestrian crossing sign with the word "NYC." The collage style gives a comprehensive view of the city's vibrant atmosphere, captured from different angles and perspectives.
# [46/18444] Captioning thumbnails_travel/-BnUY5z0Qcg.jpg ...
# This is a colorful image of three individuals standing next to a pickup truck. The truck is parked outdoors with vegetation and greenery visible in the background. Atop the vehicle, there are two suitcases that suggest travel or adventure. In the foreground, two people appear to be posing for the photo, smiling at the camera; they seem to be enjoying the moment. The third person is partially hidden by the truck, but they are also looking towards the camera with a smile.
#
# The image has text overlaid on it, including the words "Balahaw Gonagam Part 2" in bold white and black lettering at the top right corner. Additionally, the thumbnail features the name "BALAHAW" prominently displayed in large white letters against a black background at the bottom center. The overall style of the image is casual and cheerful, with a focus on the truck and the people around it. It seems to be promoting a travel or adventure content series.
# [47/18444] Captioning thumbnails_travel/-C8wGOu0Bpw.jpg ...
# The image is a digital composite showcasing a woman standing outdoors with an airplane behind her, overlaid with text that reads "Pakistan to SF" and "Samsung Galaxy $10." The text has various colors and fonts, indicating different elements such as the country name and the phone model. In the background, there is another person partially visible, suggesting a social gathering or public event.
# [48/18444] Captioning thumbnails_travel/-CE4SwWxJT8.jpg ...
# The image features a person standing in front of a van with their arms outstretched, smiling towards the camera, positioned in the foreground against a backdrop of a mountainous landscape. The sky above is partly cloudy. Text overlay at the top right corner reads "Ribo Camiguin," suggesting the name of a traveler or photographer and the location.
# [49/18444] Captioning thumbnails_travel/-CSMfkbM2QY.jpg ...
# The image shows a group of people standing together on a street with colorful graffiti in the background, featuring vibrant buildings and people in casual clothing. A yellow flag with the number 1K is prominently displayed in front of them. The text "COLOMBIA" is visible on a building behind them, and the phrase "3K WALKING TOUR" is written at the bottom of the image. The overall style suggests a travel advertisement or promotional poster for a guided tour company.
# [50/18444] Captioning thumbnails_travel/-CWQmTInsQY.jpg ...
# The image is a screenshot of a YouTube thumbnail with a vibrant photograph as its background featuring a person in winter clothing standing near a waterfall. Overlaid on the image is colorful text that reads "December in ICELAND," with a red, yellow, and blue gradient around it, creating a festive atmosphere. The style of the image is informative and promotional, typically used to advertise travel content related to the holiday season in Iceland.
# [51/18444] Captioning thumbnails_travel/-CnEIJxzHI0.jpg ...
# This is a vertical image displaying a collage of two photographs within a larger image. The primary image shows a man and woman sitting together inside a vehicle with a window to the left. They both appear happy and are facing each other. Above their heads, there's a clear sky. The secondary images are smaller and show an outdoor scene, with text overlaid that reads "EXPLORING ZAMALEK" and "SAME KO TAZAMILEK," suggesting the location or activity captured in these photos. The style of the image is candid and seems to convey a personal travel story.
# [52/18444] Captioning thumbnails_travel/-CzOvqqnQS0.jpg ...
# This is a photograph that features an individual holding plates of Indian cuisine which include naan bread, a bowl of sauce, a dish with meat, and a side dish, all presented on a tray at an outdoor dining area. The person is smiling and wearing casual attire; behind them, there are several people sitting at the table, enjoying their meals. The style of the image appears to be a snapshot taken in real life, possibly for a food blog or travel vlog, capturing the experience of enjoying Indian cuisine in an informal dining setting.
# [53/18444] Captioning thumbnails_travel/-DQjwBEJ4v4.jpg ...
# The thumbnail features a split image composition with the upper half showing a person taking a selfie with Paris's Eiffel Tower in the background, overlaid with text that reads "Парис и Влог Вологод - Салваж и Скиталес," which is likely the title of a YouTube video. The lower half of the image contains a collage with various food items, including what appears to be a dish containing meatballs or meat-based spheres, and is labeled "Вологод" in bold, capital letters, accompanied by an image of another person's face who seems to be enjoying the meal. The style of the thumbnail suggests that it could be the cover for a travel or food-related video, possibly from a channel that features both experiences.
# [54/18444] Captioning thumbnails_travel/-DSQJ6hllNI.jpg ...
# The thumbnail for a YouTube video is an image featuring a man standing with his hands on his hips, positioned slightly to the left of a vibrant cityscape background that includes palm trees and neon signs. The scene is depicted as if taken from a tourist's perspective in front of a landmark with the text "FLORIDA 48 @at" at the top center. In the foreground, there's a graphic overlaying text such as "#vlog" and other social media hashtags like "#miami" and "#travel." The style is reminiscent of a vacation vlog, with a clear focus on the traveler in front of the exotic location, suggesting an adventurous or leisurely theme for the video.
# [55/18444] Captioning thumbnails_travel/-DYz6Gd20DY.jpg ...
# The image is a thumbnail for a YouTube video titled "THAILAND BLOG." It features a woman sitting in a boat with beautiful mountain scenery in the background, wearing a blue top and sunglasses, looking towards the camera. The image has a warm and inviting color palette that includes pastel shades of blue, yellow, and green. There are texts overlaying the image, including "THAILAND BLOG" at the top and smaller text indicating the channel name or category. The style appears to be travel or lifestyle oriented, showcasing a leisurely scene that suggests an experience related to travel, adventure, or vacation in Thailand.
# [56/18444] Captioning thumbnails_travel/-DbmrWvHEUI.jpg ...
# The image showcases a vibrant collage of four photos capturing the essence of Santorini, Greece. The top-left photo presents a breathtaking view of the coastline during sunset, where the deep blue sky meets the calm sea at the horizon, creating an enchanting backdrop for the Greek island. Moving to the top-right corner, we see a picturesque white church perched on a cliff, symbolizing the rich cultural heritage of Santorini. The bottom-left photo brings us closer to everyday life on the island, capturing a young woman in white shorts and sunglasses, standing in front of the iconic blue dome of the church, seemingly enjoying her time in this paradise. Lastly, the bottom-right photo shows a person standing on the left side of the image, holding a handbag, providing a sense of scale to the vastness of the island. The photos are arranged in a square grid format, each capturing a unique moment in Santorini's picturesque landscape.
# [57/18444] Captioning thumbnails_travel/-DsAdHiMeUc.jpg ...
# The image features a split-screen with two distinct halves. On the left side of the image, there's a man with a beard and mustache, wearing a black T-shirt and a dark-colored cap. He is sitting in front of a red-framed wall that has an abstract design. To his right, on the right side of the split-screen, there's a close-up photo of a person who appears to be a man with light skin, facial hair, and a contemplative expression. The text overlaying the image in bold white letters reads "WHY HE CALLED HER OUT." The background of this portion is blurred but shows what seems to be an indoor setting with a neutral-colored wall. The style of the image suggests it's designed for a YouTube thumbnail, featuring text and images meant to convey a message or engage viewers.
# [58/18444] Captioning thumbnails_travel/-ECi-7CvvzE.jpg ...
# The image features a woman seated amidst an array of colorful clothing items, with a cat resting atop some of them. A large stack of variously colored towels forms a backdrop behind her. She appears to be smiling and is dressed in casual attire. The setting seems to be indoors, with a glimpse of a white door visible in the background. Superimposed on the image are several text elements that read "Pack with me for Cancun!" accompanied by various clothing items and accessories such as towels, bikinis, and luggage tags, suggesting an upcoming trip to Cancun. The style of the thumbnail is vibrant and eye-catching, designed to evoke a sense of travel and excitement about packing for a vacation in Cancun.
# [59/18444] Captioning thumbnails_travel/-EQPQO-8YdI.jpg ...
# The image appears to be a mosaic of various photographs from Japan, showcasing different elements typically associated with the country. It includes images of Japanese cuisine like ramen, sushi, and tempura; picturesque scenery featuring cherry blossoms and mountains; a vibrant street scene in Tokyo's Harajuku district; and a close-up view of a kokeshi doll, a traditional Japanese artifact. The collage is set against a background that seems to be a beach with palm trees, which could suggest the content creator may have visited these places or finds them appealing. The style of the thumbnail suggests it's for a travel vlog, aiming to share personal experiences and highlights from Japan.
# [60/18444] Captioning thumbnails_travel/-ERBizuiL1M.jpg ...
# The image is a photograph-style thumbnail with vibrant colors depicting a family of three, including two adults and a child, canoeing down a river. They are wearing life jackets for safety. The background shows the skyline of a city with a large body of water, and there's an overlay of text with a gradient from purple to pink that reads "Week 41 Czech Republic" in white letters. Additionally, there is a smaller text at the bottom right corner that says "Szech Republic." The overall style of the thumbnail suggests it is related to travel or exploration content, possibly from a YouTube channel about family adventures or a vlog documenting their experiences while traveling through different countries.
# [61/18444] Captioning thumbnails_travel/-EeQhWrcKyM.jpg ...
# The thumbnail features a man standing with his hands outstretched against an urban cityscape backdrop at sunset. He has short hair and a casual shirt, looking toward the viewer with a friendly gesture. Above him, a text overlay reads "Kuala Lumpur & Budget Trip 504 KM" in white on a black background. The sky is painted with warm hues of orange, yellow, and red, providing a dramatic contrast to the cityscape. The architecture of the buildings suggests a modern Asian city, possibly indicating that this video may be about travel experiences or budgeting for traveling to Malaysia.
# [62/18444] Captioning thumbnails_travel/-EmoJmXQPMM.jpg ...
# The image is a digital collage that showcases a vibrant city nightlife scene with a mix of photographs featuring French architecture, food, fashion, and a person posing against a Parisian backdrop. It combines multiple perspectives and themes into one thumbnail, suggesting an exploration or celebration of Parisian culture through various lenses.
# [63/18444] Captioning thumbnails_travel/-FflILPMWBQ.jpg ...
# This is a colorful and vibrant thumbnail from a YouTube video featuring two young children wearing swimming gear and holding inner tubes, smiling and posing next to an adult woman who is partially submerged in water and holding them. In the background, there's a sunny sky with a clear blue expanse, reinforcing the summer, outdoor setting, likely at a resort or pool. The image has a cheerful vibe, emphasizing fun and family activities. Text elements include "YOUTUBE," which indicates that this is an image designed to be used as a thumbnail for a video on the YouTube platform, and a graphic of sunbeams next to the text "SUMMER," suggesting that the video may be about summer activities or experiences.
# [64/18444] Captioning thumbnails_travel/-FfqpB7B1eo.jpg ...
# The image shows a collage of three distinct photos, all seemingly related to the subject of "Pablo Escobar." At the top, there's a photo of Pablo Escobar himself, followed by two images of people in a setting that resembles a courtroom or legal environment. The text overlay is a title that reads "Inside the luxury jail of Pablo Escobar," suggesting that the content might be an exploration into the lifestyle or living conditions of Pablo Escobar within his prison environment.
# [65/18444] Captioning thumbnails_travel/-G-gtlyR2uw.jpg ...
# The image is a composite of two different photographs, both featuring a woman in front of a backdrop that resembles a Japanese temple with Japanese characters, suggesting an attraction or event. The left side of the image shows a real-life photograph of a woman standing in front of a temple, posing with her hands on her hips and looking directly at the camera. She has short hair, is wearing glasses, and there is a visible tattoo on her right arm.
#
# The right side of the image displays a graphic representation of the same scene but with a stylized twist. This graphic includes the text "Ultimate Kyoto 3 day itinerary" in white text overlaying the image, signifying that the content may be related to travel planning or tourism in Kyoto. The overall style of the image suggests that it is likely a thumbnail for a YouTube video, given its design and layout which are commonly used for online video platforms.
# [66/18444] Captioning thumbnails_travel/-G5YOFrqGRw.jpg ...
# A woman stands on a beach taking a selfie with her cell phone, holding it up to capture the photo. She has a handbag over her shoulder and is wearing a sleeveless top and shorts. The background shows a sunset and the text "PHILIPPINES CORON" across the image.
# [67/18444] Captioning thumbnails_travel/-GbqcfbbBi4.jpg ...
# ...
# [688/18444] Captioning thumbnails_travel/1TIWBKnfoTE.jpg ...
# The image appears to be a photograph that has been edited to include two separate images placed side by side. On the left, there is an image of the Golden Gate Bridge with the word "SAN FRANCISCO" prominently displayed in the upper right corner. To its right, a second image captures a moment where a couple stands in front of a sign that reads "ALCATRAS ISLAND" and includes a reference to a first-time visitor's experience. The style of the image suggests it may be part of a travel vlog or personal sharing of a memorable visit to San Francisco.
# [689/18444] Captioning thumbnails_travel/1U2RxcE4TPM.jpg ...
# The image appears to be a screenshot from a video platform featuring two individuals engaged in an outdoor conversation. One person, visible only from the waist up, holds what looks like a red flag with white text, while the other individual stands with their arms outstretched. They are both situated in a residential area, as indicated by houses and a tree in the background. The image has overlaid text which reads "UNITED STATES OF ARABS" in bold white letters on a black background at the top right corner. The overall style is candid and appears to capture a moment from a conversation or interaction between the two individuals, possibly discussing their shared heritage or political stance.
# [690/18444] Captioning thumbnails_travel/1U6mkCs-XVc.jpg ...
# The thumbnail features a woman enjoying a meal at a restaurant with a plate of spaghetti noodles in front of her. She is seated at a dining table and has a playful expression on her face as she holds a piece of food up to her mouth, possibly savoring the taste or about to eat it. The name "Xian" is prominently displayed in bold letters across the image, suggesting that it could be related to the content creator's name or perhaps a theme or title for the video. The style of the thumbnail is casual and fun, with vibrant colors and a simple composition focused on the woman and her meal, which gives a sense of enjoyment and leisurely dining experience.
# [691/18444] Captioning thumbnails_travel/1UBmODqrFIQ.jpg ...
# The thumbnail features a woman in casual attire standing in an apartment room with her arms outstretched, posing for the camera. In front of her, there's a pink text overlay that reads "MOVING INTO MY FIRST APARTMENT | NEW YORK CITY" suggesting that she has recently moved into a first-time apartment in New York City. The image is taken during daylight, and the room appears to be well-lit with natural light.
# [692/18444] Captioning thumbnails_travel/1UIJkAF5xpI.jpg ...
# The YouTube thumbnail is a collage of four different images, showcasing travel destinations. In the top left image, there's a person holding a phone taking a selfie with a famous landmark in the background. The middle image features a beautiful beach scene with white sand and crystal blue water. The bottom right image presents a bustling city street lined with shops and people going about their day. In the bottom left corner of the collage, there's a text overlay that says "macauvlog", indicating the name of the YouTube channel, and the phrase "travel guide", suggesting the content of the video. The overall style of the thumbnail is vibrant and visually appealing, designed to attract potential viewers with its diverse representation of travel experiences.
# [693/18444] Captioning thumbnails_travel/1UZljNBN0wk.jpg ...
# The image is a collage of three photographs featuring a person eating at an outdoor cafe with a view of Taipei skyline in the background, a close-up of a plate of food, and another of a sandwich and a drink on a table. Atop these images, there is a text overlay that reads "4 DAYS IN TAIPEI" with the dates "12-30 JUNE 2022" beneath it. The thumbnail uses a vertical composition, with each photograph occupying a third of the image's height.
# [694/18444] Captioning thumbnails_travel/1UeEXDBITF0.jpg ...
# The image features a composite photograph of Rio de Janeiro's iconic Sugarloaf Mountain with a statue at its peak and the Christ Redeemer monument nearby, set against a cityscape including the Guanabara Bay and mountains in the distance. Atop the image is a logo for Brazil with a green circle around it and text that reads "برازيل" overlaying the top half of the photo. Below this, there's a watermark or emblem resembling a globe with "Brazil" written on it in English. The lower half contains text that appears to be in Arabic script, and there is a small bird perched towards the bottom right corner. This style suggests a promotional or informative image likely meant for an audience with knowledge of Brazilian landmarks, possibly for travel or tourism purposes.
# [695/18444] Captioning thumbnails_travel/1UiqIZGb3vU.jpg ...
# The image is a collage of several photos featuring a person sitting at a dining table with a view of a cityscape, another photo shows a dining scene with various food items on a table, a photo of a cake with a fork in it, and multiple images of pastries and desserts arranged neatly. The text overlay reads "Paris Dining Guide 🥐🥐 Dessert Tours & Pastries in Paris." This suggests that the collage is an advertisement for dining experiences in Paris, specifically focusing on desserts and dessert tours.
# [696/18444] Captioning thumbnails_travel/1Umf657QX24.jpg ...
# The image appears to be a photograph of two people standing on a high vantage point overlooking a vast body of water with a clear blue sky above, and there's an island visible in the distance. In the foreground, one person is taking a selfie with the other, who seems to be gesturing towards the view. The text "TANGER" is prominently displayed across the center of the image, possibly indicating a location or theme related to travel or exploration. There's also an emoji-like symbol resembling a flag, and below it is the word "FLAG," which might be referring to the flag of Tangier. The overall style of the image suggests that it could be associated with a travel vlog or a personal blog about travel experiences, given the subject matter and the presence of the "TANGER" text, which may represent a specific destination or location.
# [697/18444] Captioning thumbnails_travel/1VASEMf2kIg.jpg ...
# This image captures a vibrant scene at Gyeongbokgung Palace in South Korea during winter. It features a family posing for a photo, with a beautiful backdrop of traditional Korean architecture and cultural elements such as hanok houses and the Changdeokgung palace gate. The text on the image reads "Seoul South Korea Winter Trip" and includes hashtags like "#WinterEyeDo", indicating that they are sharing their travel experiences through this platform.
# [698/18444] Captioning thumbnails_travel/1VKk0aNEa20.jpg ...
# The image depicts a photograph of an urban street scene in Bologna, Italy, with a tall arched bridge leading to a traditional European-style building featuring a clock tower, surrounded by narrow streets with buildings on both sides, and the sky above. The sky is overcast, and there is a watermark text "BOLONA ITALY" on the photo in white font at the top left corner, overlaying the image. The style of the thumbnail suggests it is likely promotional or informational content related to travel or exploration of Italy.
# [699/18444] Captioning thumbnails_travel/1VrCOj45Rzg.jpg ...
# The image features a collage of two photos related to music. On the left side, there's an artistic rendition of a man with dark hair, wearing sunglasses, holding what appears to be a camera, set against a backdrop that resembles a painting or drawing. This style is reminiscent of a pop art portraiture. On the right side, there's a photograph of a person's hands playing a keyboard, with the fingers poised over the keys, depicting an intense moment during a performance. The central focus of the image is a man in a blue shirt, also holding a camera and aiming it towards the viewer, positioned between these two photos, suggesting his involvement or interest in both aspects of music: art and performance. The top right corner features text that says "LOUIS COLE CHORD TUTORIAL," indicating the content of the video, which is presumably a tutorial on playing chords on the guitar.
# [700/18444] Captioning thumbnails_travel/1W2Q3r1Spv8.jpg ...
# The image is a collage of several smaller photographs placed together to form a larger composite picture that appears to be a travel montage featuring multiple individuals posing for selfies and participating in various beachside activities. The central theme seems to revolve around leisure, vacationing, and relaxation at the beach. The background includes a tropical setting with palm trees, blue sky, and water, which suggests a warm climate. There is an overlaid text on the image that reads "GIRLS TRIP TO CANCUN, MEXICO" followed by a series of hashtags like "#SpringBreak", "#Vacation", "#BeachTrip", and "#Sisters". The style is informal and casual, with an emphasis on capturing candid moments from the trip.
# [701/18444] Captioning thumbnails_travel/1W67tqfw0nU.jpg ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 78
#      74     print(f"[DONE] Saved descriptions to {OUTPUT_CSV}")
#      77 if __name__ == "__main__":
# ---> 78     main()
#
# Cell In[2], line 58, in main()
#      56 print(f"[{i}/{len(img_paths)}] Captioning {path} ...")
#      57 try:
# ---> 58     caption = describe_with_llava(path)
#      59 except Exception as e:
#      60     print(f"   [ERROR] {path}: {e}")
#
# Cell In[2], line 32, in describe_with_llava(image_path)
#      23 img_b64 = encode_image_to_base64(image_path)
#      25 payload = {
#      26     "model": MODEL_NAME,
#      27     "prompt": PROMPT,
#      28     "stream": False,
#      29     "images": [img_b64],
#      30 }
# ---> 32 resp = requests.post(OLLAMA_URL, json=payload)
#      33 resp.raise_for_status()
#      35 data = resp.json()
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/youtube_thumbnail_title_creator/venv/lib/python3.9/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:
